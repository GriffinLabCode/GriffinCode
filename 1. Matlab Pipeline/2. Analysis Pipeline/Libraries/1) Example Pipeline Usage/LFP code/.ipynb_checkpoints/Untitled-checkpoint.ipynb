# %% [markdown]
# Libraries

# %%
import scipy.io as sio
from pylab import *
rcParams['figure.figsize']=(12,3)                   # Change the default figure size
import matplotlib.pyplot as plt

# %% [markdown]
# Load in signal data

# %%
data = sio.loadmat('spikefieldData.mat')
lfp = data["lfp"][0,:]
spikeTimes = data["spikeTimes"][0,:]
print(lfp.shape)
print(type(lfp))
print(lfp[0:1000].shape)
print(spikeTimes.shape)
#lfp[0,0:1000].shape
# Out:
# (1325125,)
# <class 'numpy.ndarray'>
# (1000,)
# (1325125,)

# %% [markdown]
# plot

# %%
plt.plot(lfp[0:10000])
