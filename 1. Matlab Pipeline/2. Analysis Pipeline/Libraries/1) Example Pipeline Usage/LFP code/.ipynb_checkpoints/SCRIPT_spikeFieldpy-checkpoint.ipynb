# %% [markdown]
# # Spike field coherence
# This code shows a method to estimate the relationship between action potential discharging and the ongoing LFP signal.
# This method works by calculating an FFT over the LFP and boolean spiketrain, as well as calculating the cross-spectral power denisty.
#
# Magnitude squared coherence is defined as c = (abs(S12)**2)/(S1*S2)
#
# - We will use data from Pastalkova et al., 2013, where place-cells were recorded with LFP
# - We would expect that the place-cell should be synchronized to the LFP at theta
# - This alternative approach that I developed (really just magnitude squared coherence, nothing fancy or novel) came from looking over Mark Kramers work, https://mark-kramer.github.io/Case-Studies-Python/11.html, Mike Cohens work, as well as knowing the relationship between the place-cell and LFP rhythm.

# %% [markdown]
# Import libraries

# %%
# import libraries
import scipy.io as sio
from pylab import *
rcParams['figure.figsize']=(12,3)                   # Change the default figure size
import matplotlib.pyplot as plt

# %% [markdown]
# Load in signal data and get data into formats that we can work with. We also need to define the dt variable to get time offset between samples

# %%
# load and extract data
data       = sio.loadmat('spikefieldData.mat')
srate      = data["srate"][0][0]
lfp        = data["lfp"][0,:]
spikeTimes = data["spikeTimes"][0,:]

# create a time variable
t = np.linspace(0,len(spikeTimes)/srate,len(spikeTimes))

# get time offset between samples (sampling interval)
dt = t[1]-t[0]

# %% [markdown]
# plot example signal

# %%
plt.plot(t[0:10000],lfp[0:10000])
xlabel("Time (sec)")
ylabel("Voltage")
# Out:
# Text(0, 0.5, 'Voltage')

# %% [markdown]
# #### Design spike field coherence algorithm

# %% [markdown]
# Try welch's method

# %%
# power spectrum
from scipy.signal import welch
f,Ptemp = welch(lfp,srate.astype(float),window = 'hann',nperseg=srate)
plt.plot(f,Ptemp)
xlim(1, 20)
xlabel("Frequency (Hz)")
ylabel("Power")
# Out:
# Text(0, 0.5, 'Power')

# %% [markdown]
# Wrap into a function now

# %%
def spikeFieldCoherence(lfp,spikeTimes,srate):
    from scipy.signal import welch, csd
    #from scipy.signal import csd
    f,S1  = welch(lfp,srate.astype(float),window='hann',nperseg=srate)
    f,S2  = welch(spikeTimes,srate.astype(float),window='hann',nperseg=srate)
    f,S12 = csd(lfp,spikeTimes,srate.astype(float),window='hann',nperseg=srate)
    c = (abs(S12)**2)/(S1*S2)
    plt.plot(f,c)
    xlim(1,20)
    xlabel("Frequency (Hz)")
    ylabel("Coherence (spikes-LFP)")
    return c

# %%
C = spikeFieldCoherence(lfp,spikeTimes,srate)
